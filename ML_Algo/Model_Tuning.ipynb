# %% [markdown]
# #### Model Tuning
# 1. there is thing initially we have learned how to build a machine learning models but there is one big truth about models :
# 2. the first version of your model is never the best version that is where model tuning comes in.
#
# #### cross validation
# 1. i have my data -> train split -> 80% training data , 20% testing data
# 2. k-fold cross validation like i can divide the data into k parts ->like every part will be my testing data and remaining training
# -> like step-1 i last part for testing , step-2 i took second last for testing data and so on like every time i can verify for differently
#
#
# #### hyper parameter tuning
#
# 1. Ridges & laso regression = alpha = learning root
# 2. KNN -> n-neighbour[3,5,6 ---]
# 3. decision tree -> max depth, minimum sample split
# 4. max feature
# 5. svm -> kernal
# 6. random forest ->
#
#
# 1. method to creating a hyper parameter
#
# 1. manual search
# 2. grid search cv
# 3. randomized search
#
#
# 2. grid search cv -> knn ,
# N = [3,5,7,9,11,13]
# weight = ["uniform","distance"]
# metric = ["manhatten","euclidian"]
#
# we have a so many option based on that i have to select  grid search
#
# cv : cross validation
#
# 3. Random search cv -> knn (it will search random) assume if the iteration is > 2000 then we have to used random search cv
#
#
# ##### [ Data -> model -> CV -> grid ] = perfect model
#
#
# #### ensemble learning -> 3 method
#
# 1. Bagging  -> Random forest
# 2. Boosting -> Ada boost, Grodient Boost, XG Boost (competition)
# 3. stacking
#
# 1. stacking :- multiple model ki performance ko stack kerta hai
# like multiple model we can used and based on that we will give the weight
# assume there is 3 different model
# model-1 correct prediction count is 10
# model-2 correct prediction count is 5
# model-3 correct prediction count is 8
#
# we will give the priority to model-1 because it gives the correct answer most of the times
#
# 2. begging -> boot strap aggregation  -> Random forest we can used
#
# here also we will create a model
#
# but we are using the same model -> assume 2000 data points
#
# random 1000 -> data1
# random 1000 -> data2
# random 1000 -> data3
# random 1000 -> data4
#
# now svm model will train multiple times with different different models
#
# based on query all the five model will predict the answer and based on that we will get the answer
#
# 3. boosting -> i have a multiple model assume 2000 data points
#
# M1 -> 2000 data like model1 will also give some wrong answer.
# M2 -> it will solve the issue and give the answer
# M3 -> it will resolve the issue that gives by model 2
#
# boosting is very much important in supervised learning
